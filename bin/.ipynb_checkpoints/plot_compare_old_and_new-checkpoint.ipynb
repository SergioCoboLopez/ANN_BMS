# %%
#This code computes medians of errors and uses bootstrapping to calculate errors of medians

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import matplotlib.gridspec as gridspec
import ast
import sys
sys.path.append('machine-scientist/')
sys.path.append('machine-scientist/Prior/')
from mcmc import *
from parallel import *
from fit_prior import read_prior_par
from sklearn.metrics import mean_squared_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import mean_absolute_error
from scipy.stats import bootstrap

# %%
errors_approximation=pd.read_csv('../data/'+ 'all_errors' + '.csv',index_col=0)
display(errors_approximation)

columns=["sigma", "function","rmse_nn_train", "rmse_nn_test", "rmse_mdl_train", "rmse_mdl_test"]
errors_approximation=errors_approximation[columns]
display(errors_approximation)
# Out:
#      sigma    function  mae_nn_train  mae_nn_test  mae_mdl_train  \
# 0      0.0  leaky_ReLU      0.014531     0.047835       0.000799
# 1      0.0  leaky_ReLU      0.038948     0.250292       0.007437
# 2      0.0  leaky_ReLU      0.007357     0.153327       0.005103
# 3      0.0  leaky_ReLU      0.019419     0.311185       0.001652
# 4      0.0  leaky_ReLU      0.006737     0.059373       0.002559
# ..     ...         ...           ...          ...            ...
# 655    0.2        tanh      0.077065     0.121007       0.025333
# 656    0.2        tanh      0.082055     0.125623       0.083983
# 657    0.2        tanh      0.092784     0.114085       0.094920
# 658    0.2        tanh      0.090931     0.285506       0.059270
# 659    0.2        tanh      0.089218     0.069779       0.072809
#
#      mae_mdl_test  rmse_nn_train  rmse_nn_test  rmse_mdl_train  rmse_mdl_test  \
# 0        0.032633       0.019052      0.056589        0.001039       0.045034
# 1        0.197682       0.043878      0.270347        0.010081       0.218711
# 2        0.175677       0.009675      0.183943        0.006735       0.206563
# 3        0.067233       0.047197      0.320803        0.002061       0.080441
# 4        1.141700       0.014963      0.067198        0.002954       1.636346
# ..            ...            ...           ...             ...            ...
# 655      0.127387       0.108053      0.141900        0.040428       0.134413
# 656      0.275630       0.116901      0.130110        0.118438       0.277328
# 657      0.028182       0.122117      0.114988        0.116271       0.031750
# 658      0.319420       0.115085      0.288816        0.077461       0.427289
# 659      0.896364       0.122671      0.082265        0.081451       1.028971
#
#      n  r
# 0    0  0
# 1    1  0
# 2    2  0
# 3    3  0
# 4    4  0
# ..  .. ..
# 655  5  2
# 656  6  2
# 657  7  2
# 658  8  2
# 659  9  2
#
# [660 rows x 12 columns]
#      sigma    function  rmse_nn_train  rmse_nn_test  rmse_mdl_train  \
# 0      0.0  leaky_ReLU       0.019052      0.056589        0.001039
# 1      0.0  leaky_ReLU       0.043878      0.270347        0.010081
# 2      0.0  leaky_ReLU       0.009675      0.183943        0.006735
# 3      0.0  leaky_ReLU       0.047197      0.320803        0.002061
# 4      0.0  leaky_ReLU       0.014963      0.067198        0.002954
# ..     ...         ...            ...           ...             ...
# 655    0.2        tanh       0.108053      0.141900        0.040428
# 656    0.2        tanh       0.116901      0.130110        0.118438
# 657    0.2        tanh       0.122117      0.114988        0.116271
# 658    0.2        tanh       0.115085      0.288816        0.077461
# 659    0.2        tanh       0.122671      0.082265        0.081451
#
#      rmse_mdl_test
# 0         0.045034
# 1         0.218711
# 2         0.206563
# 3         0.080441
# 4         1.636346
# ..             ...
# 655       0.134413
# 656       0.277328
# 657       0.031750
# 658       0.427289
# 659       1.028971
#
# [660 rows x 6 columns]

# %%
#Melt dataframe to plot
errors_approximation=pd.melt(errors_approximation,id_vars=["sigma","function","rmse_nn_test","rmse_mdl_test"], var_name="error_train",value_name= "value_train")
errors_approximation=pd.melt(errors_approximation,id_vars=["sigma","function", "error_train", "value_train"], var_name="error_test", value_name= "value_test")

display(errors_approximation)
# Out:
#       sigma    function     error_train  value_train     error_test  \
# 0       0.0  leaky_ReLU   rmse_nn_train     0.019052   rmse_nn_test
# 1       0.0  leaky_ReLU   rmse_nn_train     0.043878   rmse_nn_test
# 2       0.0  leaky_ReLU   rmse_nn_train     0.009675   rmse_nn_test
# 3       0.0  leaky_ReLU   rmse_nn_train     0.047197   rmse_nn_test
# 4       0.0  leaky_ReLU   rmse_nn_train     0.014963   rmse_nn_test
# ...     ...         ...             ...          ...            ...
# 2635    0.2        tanh  rmse_mdl_train     0.040428  rmse_mdl_test
# 2636    0.2        tanh  rmse_mdl_train     0.118438  rmse_mdl_test
# 2637    0.2        tanh  rmse_mdl_train     0.116271  rmse_mdl_test
# 2638    0.2        tanh  rmse_mdl_train     0.077461  rmse_mdl_test
# 2639    0.2        tanh  rmse_mdl_train     0.081451  rmse_mdl_test
#
#       value_test
# 0       0.056589
# 1       0.270347
# 2       0.183943
# 3       0.320803
# 4       0.067198
# ...          ...
# 2635    0.134413
# 2636    0.277328
# 2637    0.031750
# 2638    0.427289
# 2639    1.028971
#
# [2640 rows x 6 columns]

# %%
errors_tanh=errors_approximation[errors_approximation['function']=='tanh']
errors_leaky=errors_approximation[errors_approximation['function']=='leaky_ReLU']

display(errors_tanh)
display(errors_leaky)
# Out:
#       sigma function     error_train  value_train     error_test  value_test
# 330     0.0     tanh   rmse_nn_train     0.048355   rmse_nn_test    0.034498
# 331     0.0     tanh   rmse_nn_train     0.015287   rmse_nn_test    0.112211
# 332     0.0     tanh   rmse_nn_train     0.119820   rmse_nn_test    0.574555
# 333     0.0     tanh   rmse_nn_train     0.043636   rmse_nn_test    0.169878
# 334     0.0     tanh   rmse_nn_train     0.019958   rmse_nn_test    0.070403
# ...     ...      ...             ...          ...            ...         ...
# 2635    0.2     tanh  rmse_mdl_train     0.040428  rmse_mdl_test    0.134413
# 2636    0.2     tanh  rmse_mdl_train     0.118438  rmse_mdl_test    0.277328
# 2637    0.2     tanh  rmse_mdl_train     0.116271  rmse_mdl_test    0.031750
# 2638    0.2     tanh  rmse_mdl_train     0.077461  rmse_mdl_test    0.427289
# 2639    0.2     tanh  rmse_mdl_train     0.081451  rmse_mdl_test    1.028971
#
# [1320 rows x 6 columns]
#       sigma    function     error_train  value_train     error_test  \
# 0       0.0  leaky_ReLU   rmse_nn_train     0.019052   rmse_nn_test
# 1       0.0  leaky_ReLU   rmse_nn_train     0.043878   rmse_nn_test
# 2       0.0  leaky_ReLU   rmse_nn_train     0.009675   rmse_nn_test
# 3       0.0  leaky_ReLU   rmse_nn_train     0.047197   rmse_nn_test
# 4       0.0  leaky_ReLU   rmse_nn_train     0.014963   rmse_nn_test
# ...     ...         ...             ...          ...            ...
# 2305    0.2  leaky_ReLU  rmse_mdl_train     0.010952  rmse_mdl_test
# 2306    0.2  leaky_ReLU  rmse_mdl_train     0.140739  rmse_mdl_test
# 2307    0.2  leaky_ReLU  rmse_mdl_train     0.041776  rmse_mdl_test
# 2308    0.2  leaky_ReLU  rmse_mdl_train     0.113643  rmse_mdl_test
# 2309    0.2  leaky_ReLU  rmse_mdl_train     0.112674  rmse_mdl_test
#
#       value_test
# 0       0.056589
# 1       0.270347
# 2       0.183943
# 3       0.320803
# 4       0.067198
# ...          ...
# 2305    0.168280
# 2306    0.235492
# 2307    0.046331
# 2308    0.179149
# 2309    0.347807
#
# [1320 rows x 6 columns]

# %%
#Plot results
#Define figure size in cm                                                                           
cm = 1/2.54 #convert inch to cm                                                                     
width = 8*cm; height=6*cm

Extensions=['.png', '.pdf']

#Fonts and sizes                                                                                    
size_axis=12;size_ticks=10;size_title=5
line_w=1;marker_s=3 #width and marker size                                                          
m_size=6

output_path='../results/'

resamples=100000; bs_seed=1111
ymin=2e-4;ymax=0.75

# %%
#tanh - rmse train
fig=figure(figsize=(width,height), dpi=300)
sns.catplot(data=errors_tanh, x='sigma', y='value_train', hue="error_train", kind='point', estimator='median',
            errorbar=('ci', 95),n_boot=resamples, seed=bs_seed, palette=['red', 'green'],legend_out=False)


plt.yscale("log")

#labels, limits, and ticks
plt.xlabel(r'$\sigma$',fontsize=size_axis) 
plt.ylabel('rmse train',fontsize=size_axis)
plt.xticks(fontsize=size_ticks);plt.yticks(fontsize=size_ticks)
#plt.legend(loc='lower right',fontsize=size_ticks,frameon=False)

plt.ylim(ymin,ymax)


name_fig='tanh_rmse_train.svg'
plt.savefig(output_path+name_fig,dpi=300)

sns.catplot(data=errors_tanh, x='sigma', y='value_train', hue="error_train",palette=['red', 'green'],legend_out=False)
plt.yscale("log")
plt.ylim(1e-5,1)
plt.savefig(output_path+'dist_train_tanh',dpi=300)
plt.show()

# %%
#tanh - rmse test
fig=figure(figsize=(width,height), dpi=300)

sns.catplot(data=errors_tanh, x='sigma', y='value_test', hue="error_test", kind='point', estimator='median',
            errorbar=('ci', 95),n_boot=resamples, seed=bs_seed, palette=['red', 'green'],legend_out=False)
plt.yscale("log")

#labels, limits, and ticks
plt.xlabel(r'$\sigma$',fontsize=size_axis) 
plt.ylabel('rmse train',fontsize=size_axis)
#plt.legend(loc='lower right',fontsize=size_ticks,frameon=False)

plt.ylim(ymin,ymax)
name_fig='tanh_rmse_test.svg'
plt.savefig(output_path+name_fig,dpi=300)

sns.catplot(data=errors_tanh, x='sigma', y='value_test', hue="error_test",palette=['red', 'green'],legend_out=False)
plt.yscale("log")
plt.ylim(1e-3,10)
plt.savefig(output_path+'dist_test_tanh',dpi=300)
plt.show()

# %%
#leaky - rmse train
fig=figure(figsize=(width,height), dpi=300)

sns.catplot(data=errors_leaky, x='sigma', y='value_train', hue="error_train", kind='point', estimator='median',
            errorbar=('ci', 95),n_boot=resamples, seed=bs_seed, palette=['red', 'green'],legend_out=False)
plt.yscale("log")

#labels, limits, and ticks
plt.xlabel(r'$\sigma$',fontsize=size_axis) 
plt.ylabel('rmse train',fontsize=size_axis)
#plt.legend(loc='lower right',fontsize=size_ticks,frameon=False)

plt.ylim(ymin,ymax)
name_fig='leaky_rmse_train.svg'
plt.savefig(output_path+name_fig,dpi=300)

sns.catplot(data=errors_leaky, x='sigma', y='value_train', hue="error_train",palette=['red', 'green'],legend_out=False)
plt.yscale("log")
plt.ylim(0.9e-3,1.01)
plt.savefig(output_path+'dist_train_leaky',dpi=300)
plt.show()

# %%
#leaky - rmse test
fig=figure(figsize=(width,height), dpi=300)

sns.catplot(data=errors_leaky, x='sigma', y='value_test', hue="error_test", kind='point', estimator='median',
            errorbar=('ci', 95),n_boot=resamples, seed=bs_seed, palette=['red', 'green'],legend_out=False)
plt.yscale("log")

#labels, limits, and ticks
plt.xlabel(r'$\sigma$',fontsize=size_axis) 
plt.ylabel('rmse test',fontsize=size_axis)
#plt.legend(loc='lower right',fontsize=size_ticks,frameon=False)

plt.ylim(ymin,ymax)
name_fig='leaky_rmse_test.svg'
plt.savefig(output_path+name_fig,dpi=300)

sns.catplot(data=errors_leaky, x='sigma', y='value_test', hue="error_test",palette=['red', 'green'],legend_out=False)
plt.yscale("log")

plt.savefig(output_path+'dist_test_leaky',dpi=300)
plt.show()
