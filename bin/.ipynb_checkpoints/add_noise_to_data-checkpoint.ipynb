# %%
### This code add gaussian noise to nn-generate data. In its current version it generates 6 csv files: 3 for tanh, 3 for leaky_ReLU, with
#3 realizations of noise.
### The csv files are inputs for codes that compute traces of BMS and that train (other) neural networks.

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.gridspec as gridspec

# %%
#function='tanh' #tanh, leaky_ReLU
functions=['tanh', 'leaky_ReLU']
realizations=3 #Noise realization. 0,1,2 unless otherwise specified 
sigma=0.16;mean=0;

noise = np.random.normal(mean,sigma,sample)

file_model='NN_function_' + function + '_NREP_10_data' + '.csv'
model_d='../data/' + file_model
d=pd.read_csv(model_d)
d=d.drop(columns='Unnamed: 0')
sample=d.index.stop
print(d.index.stop)
# Out:
# 1600

# %%
d['noise']=noise
d['y_noise']=d['y'] + noise
display(d)
for function in functions:
    for realization in range(realizations):
        d.to_csv('../data/'+ 'NN_' + function + '_sigma_' + str(sigma) + '_r_' + str(realization) + '.csv')
# Out:
#         x1         y  rep     noise   y_noise
# 0    -4.00  0.018426  0.0  0.124198  0.142624
# 1    -3.95  0.018062  0.0 -0.223332 -0.205270
# 2    -3.90  0.017699  0.0 -0.077741 -0.060042
# 3    -3.85  0.017335  0.0  0.050579  0.067914
# 4    -3.80  0.016971  0.0 -0.170690 -0.153718
# ...    ...       ...  ...       ...       ...
# 1595  3.75  0.050947  9.0 -0.154799 -0.103852
# 1596  3.80  0.038210  9.0  0.330392  0.368602
# 1597  3.85  0.025473  9.0  0.055504  0.080978
# 1598  3.90  0.012737  9.0  0.008541  0.021277
# 1599  3.95  0.000000  9.0 -0.238643 -0.238643
#
# [1600 rows x 5 columns]
# 0
# ../data/NN_tanh_sigma_0.16_r_0.csv
# 1
# ../data/NN_tanh_sigma_0.16_r_1.csv
# 2
# ../data/NN_tanh_sigma_0.16_r_2.csv
# 0
# ../data/NN_leaky_ReLU_sigma_0.16_r_0.csv
# 1
# ../data/NN_leaky_ReLU_sigma_0.16_r_1.csv
# 2
# ../data/NN_leaky_ReLU_sigma_0.16_r_2.csv

# %%
n=0
dn=d[d['rep']==n]
display(dn)

#Fonts and sizes                                                                                    
size_axis=7;size_ticks=6;size_title=5
line_w=1;marker_s=3 #width and marker size

plt.plot(dn.x1,dn.y,'.',label='observed signal')
plt.plot(dn.x1,dn.y_noise,label='$\sigma$=' + str(sigma))
plt.title('n= %d ,  %s'  %(n, function)) 
plt.xlabel('x',fontsize=size_axis);plt.ylabel('y',fontsize=size_axis)
plt.xlim(-2,2);plt.ylim(-0.1,1.1)
plt.legend(loc='best')

Name_figure='nn_' + function + '_sigma_' + str(sigma) + '_n_' + str(n) + '_r_' + str(realization)
plt.savefig('../results/' + Name_figure + '.png',dpi=300)
# Out:
#        x1         y  rep     noise   y_noise
# 0   -4.00  0.018426  0.0  0.124198  0.142624
# 1   -3.95  0.018062  0.0 -0.223332 -0.205270
# 2   -3.90  0.017699  0.0 -0.077741 -0.060042
# 3   -3.85  0.017335  0.0  0.050579  0.067914
# 4   -3.80  0.016971  0.0 -0.170690 -0.153718
# ..    ...       ...  ...       ...       ...
# 155  3.75  0.956572  0.0  0.525442  1.482014
# 156  3.80  0.967429  0.0  0.168472  1.135902
# 157  3.85  0.978286  0.0  0.218342  1.196628
# 158  3.90  0.989143  0.0 -0.147634  0.841509
# 159  3.95  1.000000  0.0  0.105182  1.105182
#
# [160 rows x 5 columns]
